# %% [markdown]
# # Operator Analysis & HPT
#
# ## Objective
# 1. Find the best Mutation and Crossover operators pair for our problem
# 2. Compare the performance of our Swap Mutation and Swap Crossover operators pair with default Pymoo operators
# 3. Find the best hyperparameters such as probability for each operators.
#
# ### Steps
# 1. we identified the following 3 mutation and 4 crossover operators.
#    - Mutation:
#      - Bit Flip Mutation (BFM)
#      - Polynomial Mutation (PM)
#      - Swap Mutation (Ours)
#    - Crossover:
#      - Simulated Binary Crossover (SBX)
#      - Single Point Crossover
#      - Two Point Crossover
#      - Swap Crossover (Ours)
# 2. This gives us 12 operator pairs.
# 3. For each operator, we select 4 intervals of probability parameters; 0.2, 0.4, 0.6, 0.8. This expands our search space to 192 permutations to run.
# 4. Run `operator_analysis.py` with the relevant config.
#
# ### Reducing search space and execution time
#
# Given that each operator takes about 5 mins to run, we are looking at about 16hours to find the best operator pair for a initial population size of 10 and generations of 100. (much longer if we do the actual initial pop size of 1000.) This is only for 1 time period of `Time_ID` of 1375 and random seed of 2. We also note that in [Pymoo Hyperparameter Optimization (HPO)](https://pymoo.org/algorithms/hyperparameters.html), Optuna is used and each problems is also evaluated also different seed values, making the search space even larger.
#
# We decided to run a preliminary HPO by running the full 192 run on our "toy" model. The toy model has all the same parameters and the only difference is that the demand function integrated fitness function is replaced with a static price list to reduce computation time.
#
# **Key Assumptions**
# 1. We assume that best operator pair and hyperparameters is transferable from the toy model to the actual demand function integrated GA model.
# 2. The best operator pair and hyperparameters will be robust enough and perform well across different constraints and time periods.
#
# The logs for this run is available at `hpt_full_192.log` in the assets folder.
#
# Subsequently, we picked the best hyperparameters for each operator pair and run the final 12 permutation on the actual demand function integrated GA.
#
# The logs for this run is available at `hpt_selected_12.log` in the assets folder.
#
# **Note:** The `operator_analysis.py` also produces the `hpt_full_192.pkl` and `hpt_selected_12.pkl`. This pickle files are huge at about 6+GB and 1+GB respectively and may be available in the actual submission.

# %%
import pickle
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import pop_ga
# import GA
# from GA import PromotionOptimizationProblem, SKUPopulationSampling, SwapCrossover, SwapMutation

# %% [markdown]
# ## Full 192 Operators

# %%
res_pkl_path = '../assets/hpt_full_192.pkl'
file_size = os.path.getsize(res_pkl_path)
print(f"The size of '{res_pkl_path}' is {file_size} bytes.")
# Out:
# The size of '../assets/hpt_full_192.pkl' is 6796649103 bytes.

# %%
with open(res_pkl_path, 'rb') as f:
    result_dict = pickle.load(f)

# %%
result_dict
# Out:
# [{'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x1069a09a0>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.297766923904419},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x16c3b5f00>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.336009979248047},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x17f5a5000>,
#   'objective_value': -416160.0,
#   'elapsed_time': 2.8975203037261963},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x30909b0a0>,
#   'objective_value': -416160.0,
#   'elapsed_time': 2.857111930847168},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x30b281ba0>,
#   'objective_value': -416160.0,
#   'elapsed_time': 2.990142822265625},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x30d955c90>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.05609393119812},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x30f937a90>,
#   'objective_value': -416160.0,
#   'elapsed_time': 2.467813014984131},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x31135f850>,
#   'objective_value': -416160.0,
#   'elapsed_time': 2.8891148567199707},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x313c50790>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.557913303375244},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x316585690>,
#   'objective_value': -416160.0,
#   'elapsed_time': 2.708101987838745},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3185bdc90>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.2207839488983154},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x31af81fc0>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.648301124572754},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x31f8516c0>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.749263286590576},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x31ffc22f0>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.1508798599243164},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x32313fa30>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.2229671478271484},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x32721c370>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.069949150085449},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3291e0070>,
#   'objective_value': -416160.0,
#   'elapsed_time': 2.7579619884490967},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x32b3bd1b0>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.0662901401519775},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x32e33a6b0>,
#   'objective_value': -416156.0,
#   'elapsed_time': 2.2832589149475098},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3303db910>,
#   'objective_value': -416152.0,
#   'elapsed_time': 2.9753470420837402},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x332b8f0d0>,
#   'objective_value': -416132.0,
#   'elapsed_time': 2.8829948902130127},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x334b76c50>,
#   'objective_value': -416104.0,
#   'elapsed_time': 2.751776933670044},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x336d33730>,
#   'objective_value': -416098.0,
#   'elapsed_time': 2.671203136444092},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x33960e170>,
#   'objective_value': -416080.0,
#   'elapsed_time': 2.3371641635894775},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x33b5e8bb0>,
#   'objective_value': -416076.0,
#   'elapsed_time': 3.501332998275757},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x33e68e530>,
#   'objective_value': -416068.0,
#   'elapsed_time': 2.6317367553710938},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x342890df0>,
#   'objective_value': -416064.0,
#   'elapsed_time': 2.966547966003418},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x34415d6f0>,
#   'objective_value': -416048.0,
#   'elapsed_time': 2.592749834060669},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3446ce9b0>,
#   'objective_value': -416048.0,
#   'elapsed_time': 3.034095048904419},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x34774ab30>,
#   'objective_value': -416048.0,
#   'elapsed_time': 2.3638298511505127},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x34be41c30>,
#   'objective_value': -416040.0,
#   'elapsed_time': 3.15215802192688},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x34dcdd030>,
#   'objective_value': -415980.0,
#   'elapsed_time': 3.728158950805664},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x35058c1f0>,
#   'objective_value': -415956.0,
#   'elapsed_time': 2.4751858711242676},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3526b6530>,
#   'objective_value': -415928.0,
#   'elapsed_time': 3.422734022140503},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x354e126b0>,
#   'objective_value': -415892.0,
#   'elapsed_time': 3.287868022918701},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x356f25450>,
#   'objective_value': -415842.0,
#   'elapsed_time': 3.5483951568603516},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x35a899750>,
#   'objective_value': -415748.0,
#   'elapsed_time': 3.4455652236938477},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x35d80a410>,
#   'objective_value': -415728.0,
#   'elapsed_time': 2.2285218238830566},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x35f119510>,
#   'objective_value': -415684.0,
#   'elapsed_time': 2.1312289237976074},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x362357790>,
#   'objective_value': -415632.0,
#   'elapsed_time': 3.2195310592651367},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x128263250>,
#   'objective_value': -415486.0,
#   'elapsed_time': 3.178492784500122},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x1287e2dd0>,
#   'objective_value': -415484.0,
#   'elapsed_time': 2.192715883255005},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x128c8b4f0>,
#   'objective_value': -415376.0,
#   'elapsed_time': 2.2498393058776855},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x129b7ab90>,
#   'objective_value': -415270.0,
#   'elapsed_time': 2.7698607444763184},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x12c457fd0>,
#   'objective_value': -415268.0,
#   'elapsed_time': 2.654057025909424},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x12e694550>,
#   'objective_value': -415048.0,
#   'elapsed_time': 2.336352825164795},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x363c45600>,
#   'objective_value': -415014.0,
#   'elapsed_time': 2.794928789138794},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x368625540>,
#   'objective_value': -414944.0,
#   'elapsed_time': 2.940448045730591},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x36a5de320>,
#   'objective_value': -414776.0,
#   'elapsed_time': 2.3111701011657715},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x36e034ca0>,
#   'objective_value': -413770.0,
#   'elapsed_time': 3.0881006717681885},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3710527d0>,
#   'objective_value': -413476.0,
#   'elapsed_time': 3.527959108352661},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3731747f0>,
#   'objective_value': -413172.0,
#   'elapsed_time': 2.1856820583343506},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x375157b50>,
#   'objective_value': -412730.0,
#   'elapsed_time': 2.1492350101470947},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3779e1150>,
#   'objective_value': -412602.0,
#   'elapsed_time': 2.001124143600464},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x37a4284f0>,
#   'objective_value': -412342.0,
#   'elapsed_time': 1.7206430435180664},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x37c587be0>,
#   'objective_value': -412328.0,
#   'elapsed_time': 1.757662057876587},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3808f2a10>,
#   'objective_value': -412292.0,
#   'elapsed_time': 1.4276249408721924},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3831e38e0>,
#   'objective_value': -412224.0,
#   'elapsed_time': 1.4918289184570312},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3894d51b0>,
#   'objective_value': -412128.0,
#   'elapsed_time': 2.044631242752075},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x38bdb2a10>,
#   'objective_value': -411678.0,
#   'elapsed_time': 1.494215965270996},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x38e7a26e0>,
#   'objective_value': -411282.0,
#   'elapsed_time': 2.2068910598754883},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3920b2bc0>,
#   'objective_value': -411218.0,
#   'elapsed_time': 2.2553441524505615},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x395193e20>,
#   'objective_value': -411170.0,
#   'elapsed_time': 2.259842872619629},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x39737e8f0>,
#   'objective_value': -411156.0,
#   'elapsed_time': 2.0613350868225098},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x399cf9b10>,
#   'objective_value': -410646.0,
#   'elapsed_time': 3.0179080963134766},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x39be38250>,
#   'objective_value': -410638.0,
#   'elapsed_time': 1.6708998680114746},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3a0830820>,
#   'objective_value': -410638.0,
#   'elapsed_time': 2.0130138397216797},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3a2a0ceb0>,
#   'objective_value': -410284.0,
#   'elapsed_time': 3.0795421600341797},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3a4be15d0>,
#   'objective_value': -410270.0,
#   'elapsed_time': 1.4006288051605225},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3a75cc0a0>,
#   'objective_value': -410124.0,
#   'elapsed_time': 2.639106035232544},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3a97030a0>,
#   'objective_value': -409754.0,
#   'elapsed_time': 1.53928804397583},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3ae195150>,
#   'objective_value': -409346.0,
#   'elapsed_time': 1.5829377174377441},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3b0395660>,
#   'objective_value': -409150.0,
#   'elapsed_time': 2.0382142066955566},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3b249b040>,
#   'objective_value': -409050.0,
#   'elapsed_time': 1.4660260677337646},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3b577ccd0>,
#   'objective_value': -409006.0,
#   'elapsed_time': 1.4474859237670898},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3b92802e0>,
#   'objective_value': -408850.0,
#   'elapsed_time': 1.5569899082183838},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3bbc6aa70>,
#   'objective_value': -408734.0,
#   'elapsed_time': 1.439112901687622},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3be53c400>,
#   'objective_value': -408692.0,
#   'elapsed_time': 1.6362452507019043},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3c201f490>,
#   'objective_value': -408508.0,
#   'elapsed_time': 1.4596459865570068},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3c4c24ca0>,
#   'objective_value': -408450.0,
#   'elapsed_time': 1.80452299118042},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3c75b1600>,
#   'objective_value': -408400.0,
#   'elapsed_time': 1.5405220985412598},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3c9ea58d0>,
#   'objective_value': -408274.0,
#   'elapsed_time': 1.6101908683776855},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3cd981c60>,
#   'objective_value': -408256.0,
#   'elapsed_time': 1.7491369247436523},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3d035f1f0>,
#   'objective_value': -408108.0,
#   'elapsed_time': 1.5330359935760498},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3d2e051e0>,
#   'objective_value': -407952.0,
#   'elapsed_time': 1.4722809791564941},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3d4fe4c70>,
#   'objective_value': -407728.0,
#   'elapsed_time': 2.032357931137085},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3d89d7c40>,
#   'objective_value': -407718.0,
#   'elapsed_time': 1.5940828323364258},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3dbaec790>,
#   'objective_value': -407492.0,
#   'elapsed_time': 1.7731382846832275},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3dd690730>,
#   'objective_value': -406896.0,
#   'elapsed_time': 1.688499927520752},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3e1824ee0>,
#   'objective_value': -406850.0,
#   'elapsed_time': 1.5638470649719238},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3e43145b0>,
#   'objective_value': -406838.0,
#   'elapsed_time': 1.876007318496704},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3e6d18ac0>,
#   'objective_value': -406800.0,
#   'elapsed_time': 1.718630075454712},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3e87b7760>,
#   'objective_value': -406716.0,
#   'elapsed_time': 2.2005841732025146},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3ec8ec7c0>,
#   'objective_value': -406686.0,
#   'elapsed_time': 1.440397024154663},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3ef9b2710>,
#   'objective_value': -406576.0,
#   'elapsed_time': 1.498457908630371},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3f2368c40>,
#   'objective_value': -406104.0,
#   'elapsed_time': 2.8092942237854004},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3f55c9fc0>,
#   'objective_value': -405862.0,
#   'elapsed_time': 1.5718498229980469},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3f76b5390>,
#   'objective_value': -405728.0,
#   'elapsed_time': 1.5115976333618164},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3fb262380>,
#   'objective_value': -405474.0,
#   'elapsed_time': 1.4928948879241943},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3fdc1beb0>,
#   'objective_value': -405436.0,
#   'elapsed_time': 1.7645931243896484},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3fff4ed40>,
#   'objective_value': -405308.0,
#   'elapsed_time': 1.4936468601226807},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x402ffff70>,
#   'objective_value': -405264.0,
#   'elapsed_time': 1.9652140140533447},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x406410dc0>,
#   'objective_value': -404754.0,
#   'elapsed_time': 1.7075331211090088},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x40950eb90>,
#   'objective_value': -404604.0,
#   'elapsed_time': 1.5387871265411377},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x40b7db8e0>,
#   'objective_value': -404552.0,
#   'elapsed_time': 1.5191879272460938},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x41018f310>,
#   'objective_value': -404496.0,
#   'elapsed_time': 2.046656847000122},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x4132404f0>,
#   'objective_value': -404166.0,
#   'elapsed_time': 1.5502519607543945},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x41d3ea5c0>,
#   'objective_value': -404006.0,
#   'elapsed_time': 1.736130952835083},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4205a34f0>,
#   'objective_value': -403986.0,
#   'elapsed_time': 1.587005853652954},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4239a7100>,
#   'objective_value': -403836.0,
#   'elapsed_time': 1.7396481037139893},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x426b964d0>,
#   'objective_value': -402500.0,
#   'elapsed_time': 1.5983920097351074},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4294674f0>,
#   'objective_value': -402434.0,
#   'elapsed_time': 2.0318472385406494},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x42ae8f850>,
#   'objective_value': -402204.0,
#   'elapsed_time': 1.6258788108825684},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x42f128910>,
#   'objective_value': -401934.0,
#   'elapsed_time': 1.4396209716796875},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x4314e3c40>,
#   'objective_value': -401562.0,
#   'elapsed_time': 1.7253749370574951},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x43467d600>,
#   'objective_value': -401142.0,
#   'elapsed_time': 1.8142268657684326},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x438363490>,
#   'objective_value': -401128.0,
#   'elapsed_time': 1.6194732189178467},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x43b43d3f0>,
#   'objective_value': -401076.0,
#   'elapsed_time': 1.5199077129364014},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x43d706b60>,
#   'objective_value': -401036.0,
#   'elapsed_time': 1.4095380306243896},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x43f7d70d0>,
#   'objective_value': -400950.0,
#   'elapsed_time': 1.5212359428405762},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x44420c220>,
#   'objective_value': -400738.0,
#   'elapsed_time': 1.4528131484985352},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4464c7550>,
#   'objective_value': -400064.0,
#   'elapsed_time': 2.1194348335266113},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x448f3ba90>,
#   'objective_value': -399812.0,
#   'elapsed_time': 1.602782964706421},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x44d2dbb50>,
#   'objective_value': -399302.0,
#   'elapsed_time': 1.8795828819274902},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x44f676710>,
#   'objective_value': -399266.0,
#   'elapsed_time': 2.2094998359680176},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4538669b0>,
#   'objective_value': -399238.0,
#   'elapsed_time': 1.7584669589996338},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x455b3b910>,
#   'objective_value': -399200.0,
#   'elapsed_time': 1.472275972366333},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4585886a0>,
#   'objective_value': -398748.0,
#   'elapsed_time': 1.5978929996490479},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x45b725f60>,
#   'objective_value': -398420.0,
#   'elapsed_time': 2.1231138706207275},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x45f3b35e0>,
#   'objective_value': -398342.0,
#   'elapsed_time': 2.322232961654663},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4616605e0>,
#   'objective_value': -397732.0,
#   'elapsed_time': 1.590183973312378},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4669f1060>,
#   'objective_value': -397420.0,
#   'elapsed_time': 1.637253761291504},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x46953abf0>,
#   'objective_value': -397398.0,
#   'elapsed_time': 2.1435890197753906},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x46b6bde70>,
#   'objective_value': -397238.0,
#   'elapsed_time': 1.4161930084228516},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x46f9c89a0>,
#   'objective_value': -397148.0,
#   'elapsed_time': 2.4823079109191895},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x4724c8580>,
#   'objective_value': -396936.0,
#   'elapsed_time': 1.8207759857177734},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x476157a00>,
#   'objective_value': -396894.0,
#   'elapsed_time': 1.7782011032104492},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4782f34c0>,
#   'objective_value': -396838.0,
#   'elapsed_time': 1.6783061027526855},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x47be8c580>,
#   'objective_value': -396632.0,
#   'elapsed_time': 1.7507891654968262},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x47f215f00>,
#   'objective_value': -396488.0,
#   'elapsed_time': 1.5768539905548096},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x481513fa0>,
#   'objective_value': -396176.0,
#   'elapsed_time': 1.744189977645874},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4847a4460>,
#   'objective_value': -395974.0,
#   'elapsed_time': 1.8517000675201416},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x4883192a0>,
#   'objective_value': -395972.0,
#   'elapsed_time': 1.9204199314117432},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x48acbe860>,
#   'objective_value': -395882.0,
#   'elapsed_time': 2.2048180103302},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x48d752620>,
#   'objective_value': -395544.0,
#   'elapsed_time': 2.1205339431762695},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x491acca60>,
#   'objective_value': -395502.0,
#   'elapsed_time': 1.6557550430297852},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x493e28430>,
#   'objective_value': -395290.0,
#   'elapsed_time': 1.6538801193237305},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x495f63b80>,
#   'objective_value': -395172.0,
#   'elapsed_time': 2.004142999649048},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x49ab02740>,
#   'objective_value': -394942.0,
#   'elapsed_time': 1.5894432067871094},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x49d517d60>,
#   'objective_value': -394908.0,
#   'elapsed_time': 1.674412727355957},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4a18c6e60>,
#   'objective_value': -394354.0,
#   'elapsed_time': 2.1505987644195557},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4a4478160>,
#   'objective_value': -394282.0,
#   'elapsed_time': 1.8297522068023682},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4a6714820>,
#   'objective_value': -393898.0,
#   'elapsed_time': 2.467823028564453},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4aa2b5de0>,
#   'objective_value': -393834.0,
#   'elapsed_time': 2.3996241092681885},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4acf605e0>,
#   'objective_value': -393634.0,
#   'elapsed_time': 1.8480687141418457},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4b13064a0>,
#   'objective_value': -393630.0,
#   'elapsed_time': 1.8753788471221924},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4b34b9ba0>,
#   'objective_value': -393604.0,
#   'elapsed_time': 1.6365838050842285},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4b8851f60>,
#   'objective_value': -392708.0,
#   'elapsed_time': 1.7514128684997559},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4ba3c9270>,
#   'objective_value': -392676.0,
#   'elapsed_time': 1.6770529747009277},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x4c8224f40>,
#   'objective_value': -392660.0,
#   'elapsed_time': 1.7242248058319092},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4cb4d4640>,
#   'objective_value': -392600.0,
#   'elapsed_time': 1.8073101043701172},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4cceeae60>,
#   'objective_value': -392442.0,
#   'elapsed_time': 2.6541941165924072},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4d1387520>,
#   'objective_value': -392176.0,
#   'elapsed_time': 2.15513014793396},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4d35ddff0>,
#   'objective_value': -391946.0,
#   'elapsed_time': 1.7870090007781982},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4d816db40>,
#   'objective_value': -391800.0,
#   'elapsed_time': 1.5988237857818604},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4dabbaf20>,
#   'objective_value': -391434.0,
#   'elapsed_time': 1.887943983078003},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x4df073b20>,
#   'objective_value': -390834.0,
#   'elapsed_time': 1.5358881950378418},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4e18ed270>,
#   'objective_value': -390314.0,
#   'elapsed_time': 1.7129762172698975},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4e4463880>,
#   'objective_value': -390218.0,
#   'elapsed_time': 1.6123201847076416},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x4e7900910>,
#   'objective_value': -389500.0,
#   'elapsed_time': 1.8947563171386719},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4eab4ebf0>,
#   'objective_value': -388074.0,
#   'elapsed_time': 1.5296242237091064},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4ed5f4ac0>,
#   'objective_value': -387368.0,
#   'elapsed_time': 1.8408441543579102},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x4f11a8a90>,
#   'objective_value': -387184.0,
#   'elapsed_time': 1.5860519409179688},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4f3c59960>,
#   'objective_value': -387104.0,
#   'elapsed_time': 1.8833680152893066},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4f78f28f0>,
#   'objective_value': -385764.0,
#   'elapsed_time': 1.723541021347046},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4fa29c1f0>,
#   'objective_value': -382956.0,
#   'elapsed_time': 2.077070713043213},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4fc680130>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.8010900020599365},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x50134ee30>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.7035787105560303},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x503d32a70>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.6555991172790527},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x50790d4b0>,
#   'objective_value': -382956.0,
#   'elapsed_time': 2.1495423316955566},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x50a4f84f0>,
#   'objective_value': -382956.0,
#   'elapsed_time': 2.018921136856079},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x50cfd0a30>,
#   'objective_value': -382956.0,
#   'elapsed_time': 2.0720629692077637},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x5112b8370>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.7613449096679688},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x51369c2b0>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.6502740383148193},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x51806b2b0>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.8219642639160156},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x51b64dff0>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.7491719722747803},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x51e92d330>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.6867072582244873},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x521af7a30>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.7289087772369385},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x5250ded70>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.914780855178833},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x5282be6b0>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.828261137008667},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x529fa1ff0>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.7386260032653809},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x52e385630>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.248424768447876}]

# %%
sorted_results = sorted(result_dict, key=lambda x: x["objective_value"])
sorted_results
# Out:
# [{'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x1069a09a0>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.297766923904419},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x16c3b5f00>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.336009979248047},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x17f5a5000>,
#   'objective_value': -416160.0,
#   'elapsed_time': 2.8975203037261963},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x30909b0a0>,
#   'objective_value': -416160.0,
#   'elapsed_time': 2.857111930847168},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x30b281ba0>,
#   'objective_value': -416160.0,
#   'elapsed_time': 2.990142822265625},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x30d955c90>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.05609393119812},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x30f937a90>,
#   'objective_value': -416160.0,
#   'elapsed_time': 2.467813014984131},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x31135f850>,
#   'objective_value': -416160.0,
#   'elapsed_time': 2.8891148567199707},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x313c50790>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.557913303375244},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x316585690>,
#   'objective_value': -416160.0,
#   'elapsed_time': 2.708101987838745},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3185bdc90>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.2207839488983154},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x31af81fc0>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.648301124572754},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x31f8516c0>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.749263286590576},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x31ffc22f0>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.1508798599243164},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x32313fa30>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.2229671478271484},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x32721c370>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.069949150085449},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3291e0070>,
#   'objective_value': -416160.0,
#   'elapsed_time': 2.7579619884490967},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x32b3bd1b0>,
#   'objective_value': -416160.0,
#   'elapsed_time': 3.0662901401519775},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x32e33a6b0>,
#   'objective_value': -416156.0,
#   'elapsed_time': 2.2832589149475098},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3303db910>,
#   'objective_value': -416152.0,
#   'elapsed_time': 2.9753470420837402},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x332b8f0d0>,
#   'objective_value': -416132.0,
#   'elapsed_time': 2.8829948902130127},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x334b76c50>,
#   'objective_value': -416104.0,
#   'elapsed_time': 2.751776933670044},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x336d33730>,
#   'objective_value': -416098.0,
#   'elapsed_time': 2.671203136444092},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x33960e170>,
#   'objective_value': -416080.0,
#   'elapsed_time': 2.3371641635894775},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x33b5e8bb0>,
#   'objective_value': -416076.0,
#   'elapsed_time': 3.501332998275757},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x33e68e530>,
#   'objective_value': -416068.0,
#   'elapsed_time': 2.6317367553710938},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x342890df0>,
#   'objective_value': -416064.0,
#   'elapsed_time': 2.966547966003418},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x34415d6f0>,
#   'objective_value': -416048.0,
#   'elapsed_time': 2.592749834060669},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3446ce9b0>,
#   'objective_value': -416048.0,
#   'elapsed_time': 3.034095048904419},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x34774ab30>,
#   'objective_value': -416048.0,
#   'elapsed_time': 2.3638298511505127},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x34be41c30>,
#   'objective_value': -416040.0,
#   'elapsed_time': 3.15215802192688},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x34dcdd030>,
#   'objective_value': -415980.0,
#   'elapsed_time': 3.728158950805664},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x35058c1f0>,
#   'objective_value': -415956.0,
#   'elapsed_time': 2.4751858711242676},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3526b6530>,
#   'objective_value': -415928.0,
#   'elapsed_time': 3.422734022140503},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x354e126b0>,
#   'objective_value': -415892.0,
#   'elapsed_time': 3.287868022918701},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x356f25450>,
#   'objective_value': -415842.0,
#   'elapsed_time': 3.5483951568603516},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x35a899750>,
#   'objective_value': -415748.0,
#   'elapsed_time': 3.4455652236938477},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x35d80a410>,
#   'objective_value': -415728.0,
#   'elapsed_time': 2.2285218238830566},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x35f119510>,
#   'objective_value': -415684.0,
#   'elapsed_time': 2.1312289237976074},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x362357790>,
#   'objective_value': -415632.0,
#   'elapsed_time': 3.2195310592651367},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x128263250>,
#   'objective_value': -415486.0,
#   'elapsed_time': 3.178492784500122},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x1287e2dd0>,
#   'objective_value': -415484.0,
#   'elapsed_time': 2.192715883255005},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x128c8b4f0>,
#   'objective_value': -415376.0,
#   'elapsed_time': 2.2498393058776855},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x129b7ab90>,
#   'objective_value': -415270.0,
#   'elapsed_time': 2.7698607444763184},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x12c457fd0>,
#   'objective_value': -415268.0,
#   'elapsed_time': 2.654057025909424},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x12e694550>,
#   'objective_value': -415048.0,
#   'elapsed_time': 2.336352825164795},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x363c45600>,
#   'objective_value': -415014.0,
#   'elapsed_time': 2.794928789138794},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x368625540>,
#   'objective_value': -414944.0,
#   'elapsed_time': 2.940448045730591},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x36a5de320>,
#   'objective_value': -414776.0,
#   'elapsed_time': 2.3111701011657715},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x36e034ca0>,
#   'objective_value': -413770.0,
#   'elapsed_time': 3.0881006717681885},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3710527d0>,
#   'objective_value': -413476.0,
#   'elapsed_time': 3.527959108352661},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3731747f0>,
#   'objective_value': -413172.0,
#   'elapsed_time': 2.1856820583343506},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x375157b50>,
#   'objective_value': -412730.0,
#   'elapsed_time': 2.1492350101470947},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3779e1150>,
#   'objective_value': -412602.0,
#   'elapsed_time': 2.001124143600464},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x37a4284f0>,
#   'objective_value': -412342.0,
#   'elapsed_time': 1.7206430435180664},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x37c587be0>,
#   'objective_value': -412328.0,
#   'elapsed_time': 1.757662057876587},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3808f2a10>,
#   'objective_value': -412292.0,
#   'elapsed_time': 1.4276249408721924},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3831e38e0>,
#   'objective_value': -412224.0,
#   'elapsed_time': 1.4918289184570312},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3894d51b0>,
#   'objective_value': -412128.0,
#   'elapsed_time': 2.044631242752075},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x38bdb2a10>,
#   'objective_value': -411678.0,
#   'elapsed_time': 1.494215965270996},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x38e7a26e0>,
#   'objective_value': -411282.0,
#   'elapsed_time': 2.2068910598754883},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3920b2bc0>,
#   'objective_value': -411218.0,
#   'elapsed_time': 2.2553441524505615},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x395193e20>,
#   'objective_value': -411170.0,
#   'elapsed_time': 2.259842872619629},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x39737e8f0>,
#   'objective_value': -411156.0,
#   'elapsed_time': 2.0613350868225098},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x399cf9b10>,
#   'objective_value': -410646.0,
#   'elapsed_time': 3.0179080963134766},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x39be38250>,
#   'objective_value': -410638.0,
#   'elapsed_time': 1.6708998680114746},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3a0830820>,
#   'objective_value': -410638.0,
#   'elapsed_time': 2.0130138397216797},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3a2a0ceb0>,
#   'objective_value': -410284.0,
#   'elapsed_time': 3.0795421600341797},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3a4be15d0>,
#   'objective_value': -410270.0,
#   'elapsed_time': 1.4006288051605225},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3a75cc0a0>,
#   'objective_value': -410124.0,
#   'elapsed_time': 2.639106035232544},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3a97030a0>,
#   'objective_value': -409754.0,
#   'elapsed_time': 1.53928804397583},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3ae195150>,
#   'objective_value': -409346.0,
#   'elapsed_time': 1.5829377174377441},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3b0395660>,
#   'objective_value': -409150.0,
#   'elapsed_time': 2.0382142066955566},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3b249b040>,
#   'objective_value': -409050.0,
#   'elapsed_time': 1.4660260677337646},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3b577ccd0>,
#   'objective_value': -409006.0,
#   'elapsed_time': 1.4474859237670898},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3b92802e0>,
#   'objective_value': -408850.0,
#   'elapsed_time': 1.5569899082183838},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3bbc6aa70>,
#   'objective_value': -408734.0,
#   'elapsed_time': 1.439112901687622},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3be53c400>,
#   'objective_value': -408692.0,
#   'elapsed_time': 1.6362452507019043},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3c201f490>,
#   'objective_value': -408508.0,
#   'elapsed_time': 1.4596459865570068},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3c4c24ca0>,
#   'objective_value': -408450.0,
#   'elapsed_time': 1.80452299118042},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3c75b1600>,
#   'objective_value': -408400.0,
#   'elapsed_time': 1.5405220985412598},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3c9ea58d0>,
#   'objective_value': -408274.0,
#   'elapsed_time': 1.6101908683776855},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3cd981c60>,
#   'objective_value': -408256.0,
#   'elapsed_time': 1.7491369247436523},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3d035f1f0>,
#   'objective_value': -408108.0,
#   'elapsed_time': 1.5330359935760498},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3d2e051e0>,
#   'objective_value': -407952.0,
#   'elapsed_time': 1.4722809791564941},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3d4fe4c70>,
#   'objective_value': -407728.0,
#   'elapsed_time': 2.032357931137085},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3d89d7c40>,
#   'objective_value': -407718.0,
#   'elapsed_time': 1.5940828323364258},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3dbaec790>,
#   'objective_value': -407492.0,
#   'elapsed_time': 1.7731382846832275},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3dd690730>,
#   'objective_value': -406896.0,
#   'elapsed_time': 1.688499927520752},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3e1824ee0>,
#   'objective_value': -406850.0,
#   'elapsed_time': 1.5638470649719238},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3e43145b0>,
#   'objective_value': -406838.0,
#   'elapsed_time': 1.876007318496704},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3e6d18ac0>,
#   'objective_value': -406800.0,
#   'elapsed_time': 1.718630075454712},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3e87b7760>,
#   'objective_value': -406716.0,
#   'elapsed_time': 2.2005841732025146},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3ec8ec7c0>,
#   'objective_value': -406686.0,
#   'elapsed_time': 1.440397024154663},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3ef9b2710>,
#   'objective_value': -406576.0,
#   'elapsed_time': 1.498457908630371},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3f2368c40>,
#   'objective_value': -406104.0,
#   'elapsed_time': 2.8092942237854004},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x3f55c9fc0>,
#   'objective_value': -405862.0,
#   'elapsed_time': 1.5718498229980469},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3f76b5390>,
#   'objective_value': -405728.0,
#   'elapsed_time': 1.5115976333618164},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x3fb262380>,
#   'objective_value': -405474.0,
#   'elapsed_time': 1.4928948879241943},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x3fdc1beb0>,
#   'objective_value': -405436.0,
#   'elapsed_time': 1.7645931243896484},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x3fff4ed40>,
#   'objective_value': -405308.0,
#   'elapsed_time': 1.4936468601226807},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x402ffff70>,
#   'objective_value': -405264.0,
#   'elapsed_time': 1.9652140140533447},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x406410dc0>,
#   'objective_value': -404754.0,
#   'elapsed_time': 1.7075331211090088},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x40950eb90>,
#   'objective_value': -404604.0,
#   'elapsed_time': 1.5387871265411377},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x40b7db8e0>,
#   'objective_value': -404552.0,
#   'elapsed_time': 1.5191879272460938},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x41018f310>,
#   'objective_value': -404496.0,
#   'elapsed_time': 2.046656847000122},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x4132404f0>,
#   'objective_value': -404166.0,
#   'elapsed_time': 1.5502519607543945},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x41d3ea5c0>,
#   'objective_value': -404006.0,
#   'elapsed_time': 1.736130952835083},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4205a34f0>,
#   'objective_value': -403986.0,
#   'elapsed_time': 1.587005853652954},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4239a7100>,
#   'objective_value': -403836.0,
#   'elapsed_time': 1.7396481037139893},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x426b964d0>,
#   'objective_value': -402500.0,
#   'elapsed_time': 1.5983920097351074},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4294674f0>,
#   'objective_value': -402434.0,
#   'elapsed_time': 2.0318472385406494},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x42ae8f850>,
#   'objective_value': -402204.0,
#   'elapsed_time': 1.6258788108825684},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x42f128910>,
#   'objective_value': -401934.0,
#   'elapsed_time': 1.4396209716796875},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x4314e3c40>,
#   'objective_value': -401562.0,
#   'elapsed_time': 1.7253749370574951},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x43467d600>,
#   'objective_value': -401142.0,
#   'elapsed_time': 1.8142268657684326},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x438363490>,
#   'objective_value': -401128.0,
#   'elapsed_time': 1.6194732189178467},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x43b43d3f0>,
#   'objective_value': -401076.0,
#   'elapsed_time': 1.5199077129364014},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x43d706b60>,
#   'objective_value': -401036.0,
#   'elapsed_time': 1.4095380306243896},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x43f7d70d0>,
#   'objective_value': -400950.0,
#   'elapsed_time': 1.5212359428405762},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x44420c220>,
#   'objective_value': -400738.0,
#   'elapsed_time': 1.4528131484985352},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4464c7550>,
#   'objective_value': -400064.0,
#   'elapsed_time': 2.1194348335266113},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x448f3ba90>,
#   'objective_value': -399812.0,
#   'elapsed_time': 1.602782964706421},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x44d2dbb50>,
#   'objective_value': -399302.0,
#   'elapsed_time': 1.8795828819274902},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x44f676710>,
#   'objective_value': -399266.0,
#   'elapsed_time': 2.2094998359680176},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4538669b0>,
#   'objective_value': -399238.0,
#   'elapsed_time': 1.7584669589996338},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x455b3b910>,
#   'objective_value': -399200.0,
#   'elapsed_time': 1.472275972366333},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4585886a0>,
#   'objective_value': -398748.0,
#   'elapsed_time': 1.5978929996490479},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x45b725f60>,
#   'objective_value': -398420.0,
#   'elapsed_time': 2.1231138706207275},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x45f3b35e0>,
#   'objective_value': -398342.0,
#   'elapsed_time': 2.322232961654663},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4616605e0>,
#   'objective_value': -397732.0,
#   'elapsed_time': 1.590183973312378},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4669f1060>,
#   'objective_value': -397420.0,
#   'elapsed_time': 1.637253761291504},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x46953abf0>,
#   'objective_value': -397398.0,
#   'elapsed_time': 2.1435890197753906},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x46b6bde70>,
#   'objective_value': -397238.0,
#   'elapsed_time': 1.4161930084228516},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x46f9c89a0>,
#   'objective_value': -397148.0,
#   'elapsed_time': 2.4823079109191895},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x4724c8580>,
#   'objective_value': -396936.0,
#   'elapsed_time': 1.8207759857177734},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x476157a00>,
#   'objective_value': -396894.0,
#   'elapsed_time': 1.7782011032104492},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4782f34c0>,
#   'objective_value': -396838.0,
#   'elapsed_time': 1.6783061027526855},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x47be8c580>,
#   'objective_value': -396632.0,
#   'elapsed_time': 1.7507891654968262},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x47f215f00>,
#   'objective_value': -396488.0,
#   'elapsed_time': 1.5768539905548096},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x481513fa0>,
#   'objective_value': -396176.0,
#   'elapsed_time': 1.744189977645874},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4847a4460>,
#   'objective_value': -395974.0,
#   'elapsed_time': 1.8517000675201416},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x4883192a0>,
#   'objective_value': -395972.0,
#   'elapsed_time': 1.9204199314117432},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x48acbe860>,
#   'objective_value': -395882.0,
#   'elapsed_time': 2.2048180103302},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x48d752620>,
#   'objective_value': -395544.0,
#   'elapsed_time': 2.1205339431762695},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x491acca60>,
#   'objective_value': -395502.0,
#   'elapsed_time': 1.6557550430297852},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x493e28430>,
#   'objective_value': -395290.0,
#   'elapsed_time': 1.6538801193237305},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x495f63b80>,
#   'objective_value': -395172.0,
#   'elapsed_time': 2.004142999649048},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x49ab02740>,
#   'objective_value': -394942.0,
#   'elapsed_time': 1.5894432067871094},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x49d517d60>,
#   'objective_value': -394908.0,
#   'elapsed_time': 1.674412727355957},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4a18c6e60>,
#   'objective_value': -394354.0,
#   'elapsed_time': 2.1505987644195557},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4a4478160>,
#   'objective_value': -394282.0,
#   'elapsed_time': 1.8297522068023682},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4a6714820>,
#   'objective_value': -393898.0,
#   'elapsed_time': 2.467823028564453},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4aa2b5de0>,
#   'objective_value': -393834.0,
#   'elapsed_time': 2.3996241092681885},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4acf605e0>,
#   'objective_value': -393634.0,
#   'elapsed_time': 1.8480687141418457},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4b13064a0>,
#   'objective_value': -393630.0,
#   'elapsed_time': 1.8753788471221924},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4b34b9ba0>,
#   'objective_value': -393604.0,
#   'elapsed_time': 1.6365838050842285},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4b8851f60>,
#   'objective_value': -392708.0,
#   'elapsed_time': 1.7514128684997559},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4ba3c9270>,
#   'objective_value': -392676.0,
#   'elapsed_time': 1.6770529747009277},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x4c8224f40>,
#   'objective_value': -392660.0,
#   'elapsed_time': 1.7242248058319092},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4cb4d4640>,
#   'objective_value': -392600.0,
#   'elapsed_time': 1.8073101043701172},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4cceeae60>,
#   'objective_value': -392442.0,
#   'elapsed_time': 2.6541941165924072},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4d1387520>,
#   'objective_value': -392176.0,
#   'elapsed_time': 2.15513014793396},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4d35ddff0>,
#   'objective_value': -391946.0,
#   'elapsed_time': 1.7870090007781982},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4d816db40>,
#   'objective_value': -391800.0,
#   'elapsed_time': 1.5988237857818604},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4dabbaf20>,
#   'objective_value': -391434.0,
#   'elapsed_time': 1.887943983078003},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x4df073b20>,
#   'objective_value': -390834.0,
#   'elapsed_time': 1.5358881950378418},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4e18ed270>,
#   'objective_value': -390314.0,
#   'elapsed_time': 1.7129762172698975},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4e4463880>,
#   'objective_value': -390218.0,
#   'elapsed_time': 1.6123201847076416},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x4e7900910>,
#   'objective_value': -389500.0,
#   'elapsed_time': 1.8947563171386719},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4eab4ebf0>,
#   'objective_value': -388074.0,
#   'elapsed_time': 1.5296242237091064},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4ed5f4ac0>,
#   'objective_value': -387368.0,
#   'elapsed_time': 1.8408441543579102},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x4f11a8a90>,
#   'objective_value': -387184.0,
#   'elapsed_time': 1.5860519409179688},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4f3c59960>,
#   'objective_value': -387104.0,
#   'elapsed_time': 1.8833680152893066},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x4f78f28f0>,
#   'objective_value': -385764.0,
#   'elapsed_time': 1.723541021347046},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x4fa29c1f0>,
#   'objective_value': -382956.0,
#   'elapsed_time': 2.077070713043213},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x4fc680130>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.8010900020599365},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x50134ee30>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.7035787105560303},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x503d32a70>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.6555991172790527},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x50790d4b0>,
#   'objective_value': -382956.0,
#   'elapsed_time': 2.1495423316955566},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x50a4f84f0>,
#   'objective_value': -382956.0,
#   'elapsed_time': 2.018921136856079},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x50cfd0a30>,
#   'objective_value': -382956.0,
#   'elapsed_time': 2.0720629692077637},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x5112b8370>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.7613449096679688},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x51369c2b0>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.6502740383148193},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x51806b2b0>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.8219642639160156},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x51b64dff0>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.7491719722747803},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.6,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x51e92d330>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.6867072582244873},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x521af7a30>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.7289087772369385},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x5250ded70>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.914780855178833},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x5282be6b0>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.828261137008667},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x529fa1ff0>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.7386260032653809},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x52e385630>,
#   'objective_value': -382956.0,
#   'elapsed_time': 1.248424768447876}]

# %%
df = pd.DataFrame(sorted_results)

# Remove the 'result' column from the DataFrame
df.drop(columns=['result'], inplace=True)
df
# Out:
#     crossover  crossover_prob            mutation  mutation_prob  \
# 0         SBX             0.2        SwapMutation            0.4
# 1         SBX             0.2        SwapMutation            0.6
# 2         SBX             0.2        SwapMutation            0.8
# 3         SBX             0.4        SwapMutation            0.4
# 4         SBX             0.4        SwapMutation            0.6
# ..        ...             ...                 ...            ...
# 187       SBX             0.8  PolynomialMutation            0.2
# 188       SBX             0.8  PolynomialMutation            0.4
# 189       SBX             0.8  PolynomialMutation            0.6
# 190       SBX             0.8  PolynomialMutation            0.8
# 191       SBX             0.8        SwapMutation            0.2
#
#      objective_value  elapsed_time
# 0          -416160.0      3.297767
# 1          -416160.0      3.336010
# 2          -416160.0      2.897520
# 3          -416160.0      2.857112
# 4          -416160.0      2.990143
# ..               ...           ...
# 187        -382956.0      1.728909
# 188        -382956.0      1.914781
# 189        -382956.0      1.828261
# 190        -382956.0      1.738626
# 191        -382956.0      1.248425
#
# [192 rows x 6 columns]

# %% [markdown]
# For the toy model run, all permutations of SBX + SwapMutation is performing very well.

# %%
for idx, r in enumerate(result_dict):
    label = f'{r["crossover"]} {r["crossover_prob"]} {r["mutation"]} {r["mutation_prob"]}'
    n_evals = np.array([e.evaluator.n_eval for e in r["result"].history])
    opt = np.array([e.opt[0].F for e in r["result"].history])
    
    if idx == 0:
        plt.plot(n_evals, opt, label=label, linestyle='solid', linewidth=2)
    elif idx == 1:
        plt.plot(n_evals, opt, label=label, linestyle='--', linewidth=2)
    else:
        plt.plot(n_evals, opt, linestyle='dotted', linewidth=1, alpha=0.8)


plt.title("Analysis of Convergence")
plt.xlabel("n_eval")
plt.ylabel("f_min")
plt.legend(loc="lower left", fontsize="small")
plt.show()

# %% [markdown]
# ### Get the top 12 Operators per unique (Mutation, Crossover) tuple

# %%
idx_min_objective = df.groupby(['mutation', 'crossover'])['objective_value'].idxmin()

min_df = df.loc[idx_min_objective]

min_df = min_df.sort_values(by='objective_value', ascending=True)

# If you want to reset index
min_df.reset_index(drop=True, inplace=True)

min_df
# Out:
#                crossover  crossover_prob            mutation  mutation_prob  \
# 0                    SBX             0.2        SwapMutation            0.4
# 1   SinglePointCrossover             0.2        SwapMutation            0.8
# 2          SwapCrossover             0.8        SwapMutation            0.4
# 3      TwoPointCrossover             0.8        SwapMutation            0.8
# 4          SwapCrossover             0.8  PolynomialMutation            0.2
# 5          SwapCrossover             0.6                 BFM            0.2
# 6   SinglePointCrossover             0.8                 BFM            0.8
# 7      TwoPointCrossover             0.6                 BFM            0.6
# 8      TwoPointCrossover             0.4  PolynomialMutation            0.6
# 9                    SBX             0.2                 BFM            0.6
# 10  SinglePointCrossover             0.2  PolynomialMutation            0.8
# 11                   SBX             0.2  PolynomialMutation            0.2
#
#     objective_value  elapsed_time
# 0         -416160.0      3.297767
# 1         -416160.0      3.220784
# 2         -416160.0      3.066290
# 3         -416160.0      2.757962
# 4         -412602.0      2.001124
# 5         -412342.0      1.720643
# 6         -412292.0      1.427625
# 7         -412224.0      1.491829
# 8         -402204.0      1.625879
# 9         -400950.0      1.521236
# 10        -399812.0      1.602783
# 11        -382956.0      2.077071

# %%
unique_combinations = min_df[['crossover', 'crossover_prob','mutation', 'mutation_prob']]

unique_combinations_hashes = {hash(tuple(row)) for row in unique_combinations.values}

plt.figure(figsize=(10, 8))

for idx, r in enumerate(result_dict):
    label = f'{r["crossover"]} {r["crossover_prob"]} {r["mutation"]} {r["mutation_prob"]}'
    combination_tuple = (r["crossover"], r["crossover_prob"], r["mutation"], r["mutation_prob"])
    
    current_tuple_hash = hash(combination_tuple)
    
    if current_tuple_hash in unique_combinations_hashes:
        # print(f'Found: {combination_tuple} in unique_combinations')
        n_evals = np.array([e.evaluator.n_eval for e in r["result"].history])
        opt = np.array([e.opt[0].F for e in r["result"].history])
        
        if idx == 0:
            plt.plot(n_evals, opt, label=label, linestyle='solid', linewidth=2)
        else:
            plt.plot(n_evals, opt, label=label,linestyle='dotted', linewidth=1, alpha=0.8)
    # else:
        # print(f'Not Found: {combination_tuple} in unique_combinations')

plt.title("Analysis of Convergence")
plt.xlabel("n_eval")
plt.ylabel("f_min")
plt.legend(loc="lower left", fontsize="small")
plt.show()

# %% [markdown]
# ## Selected 12 Operators

# %%
res_pkl_path = '../assets/hpt_selected_12.pkl'
file_size = os.path.getsize(res_pkl_path)
print(f"The size of '{res_pkl_path}' is {file_size} bytes.")
# Out:
# The size of '../assets/hpt_selected_12.pkl' is 1734242215 bytes.

# %%
with open(res_pkl_path, 'rb') as f:
    result_dict = pickle.load(f)

# %%
result_dict
# Out:
# [{'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x127c20970>,
#   'objective_value': -70997.50015636685,
#   'elapsed_time': 210.40265703201294},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x153461150>,
#   'objective_value': -70975.24842109028,
#   'elapsed_time': 411.0201609134674},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x1571c0d60>,
#   'objective_value': -70896.91505522694,
#   'elapsed_time': 410.1004719734192},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x16a6fd480>,
#   'objective_value': -70830.1575942664,
#   'elapsed_time': 413.54667925834656},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x1736fc400>,
#   'objective_value': -70658.37813596158,
#   'elapsed_time': 282.9681589603424},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x17750b760>,
#   'objective_value': -70542.02379276471,
#   'elapsed_time': 148.54014801979065},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x31a9403a0>,
#   'objective_value': -70285.45612561813,
#   'elapsed_time': 224.03125381469727},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x31cfa4be0>,
#   'objective_value': -70137.07179023666,
#   'elapsed_time': 267.26724767684937},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x33156aad0>,
#   'objective_value': -69912.11038159703,
#   'elapsed_time': 277.2166690826416},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x334a93190>,
#   'objective_value': -69749.86943370735,
#   'elapsed_time': 200.94905614852905},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x341079150>,
#   'objective_value': -69724.5077801412,
#   'elapsed_time': 230.3623468875885},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x34507c820>,
#   'objective_value': -69310.63012289927,
#   'elapsed_time': 159.77542114257812}]

# %%
sorted_results = sorted(result_dict, key=lambda x: x["objective_value"])
sorted_results
# Out:
# [{'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x127c20970>,
#   'objective_value': -70997.50015636685,
#   'elapsed_time': 210.40265703201294},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x153461150>,
#   'objective_value': -70975.24842109028,
#   'elapsed_time': 411.0201609134674},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x1571c0d60>,
#   'objective_value': -70896.91505522694,
#   'elapsed_time': 410.1004719734192},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x16a6fd480>,
#   'objective_value': -70830.1575942664,
#   'elapsed_time': 413.54667925834656},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x1736fc400>,
#   'objective_value': -70658.37813596158,
#   'elapsed_time': 282.9681589603424},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x17750b760>,
#   'objective_value': -70542.02379276471,
#   'elapsed_time': 148.54014801979065},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x31a9403a0>,
#   'objective_value': -70285.45612561813,
#   'elapsed_time': 224.03125381469727},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x31cfa4be0>,
#   'objective_value': -70137.07179023666,
#   'elapsed_time': 267.26724767684937},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x33156aad0>,
#   'objective_value': -69912.11038159703,
#   'elapsed_time': 277.2166690826416},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x334a93190>,
#   'objective_value': -69749.86943370735,
#   'elapsed_time': 200.94905614852905},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x341079150>,
#   'objective_value': -69724.5077801412,
#   'elapsed_time': 230.3623468875885},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x34507c820>,
#   'objective_value': -69310.63012289927,
#   'elapsed_time': 159.77542114257812}]

# %%
df = pd.DataFrame(sorted_results)

# Remove the 'result' column from the DataFrame
df.drop(columns=['result'], inplace=True)
df
# Out:
#                crossover  crossover_prob            mutation  mutation_prob  \
# 0      TwoPointCrossover             0.4  PolynomialMutation            0.6
# 1   SinglePointCrossover             0.2        SwapMutation            0.8
# 2          SwapCrossover             0.8        SwapMutation            0.4
# 3      TwoPointCrossover             0.8        SwapMutation            0.8
# 4          SwapCrossover             0.8  PolynomialMutation            0.2
# 5   SinglePointCrossover             0.2  PolynomialMutation            0.8
# 6                    SBX             0.8  PolynomialMutation            0.8
# 7          SwapCrossover             0.6                 BFM            0.2
# 8                    SBX             0.2        SwapMutation            0.4
# 9   SinglePointCrossover             0.8                 BFM            0.8
# 10     TwoPointCrossover             0.6                 BFM            0.6
# 11                   SBX             0.2                 BFM            0.6
#
#     objective_value  elapsed_time
# 0     -70997.500156    210.402657
# 1     -70975.248421    411.020161
# 2     -70896.915055    410.100472
# 3     -70830.157594    413.546679
# 4     -70658.378136    282.968159
# 5     -70542.023793    148.540148
# 6     -70285.456126    224.031254
# 7     -70137.071790    267.267248
# 8     -69912.110382    277.216669
# 9     -69749.869434    200.949056
# 10    -69724.507780    230.362347
# 11    -69310.630123    159.775421

# %% [markdown]
# Best Operator Pairs:
#
# 1. TwoPointCrossover: 0.4, PM: 0.6
# 2. SinglePointCrossover:0.2, SwapMuation:0.8

# %%
for idx, r in enumerate(result_dict):
    label = f'{r["crossover"]} {r["crossover_prob"]} {r["mutation"]} {r["mutation_prob"]}'
    n_evals = np.array([e.evaluator.n_eval for e in r["result"].history])
    opt = np.array([e.opt[0].F for e in r["result"].history])
    
    if idx == 0:
        plt.plot(n_evals, opt, label=label, linestyle='solid', linewidth=2)
    elif idx == 1:
        plt.plot(n_evals, opt, label=label, linestyle='--', linewidth=2)
    else:
        plt.plot(n_evals, opt, label=label, linestyle='dotted', linewidth=1, alpha=0.8)


plt.title("Analysis of Convergence")
plt.xlabel("n_eval")
plt.ylabel("f_min")
plt.legend(loc="lower left", fontsize="small")
plt.show()
