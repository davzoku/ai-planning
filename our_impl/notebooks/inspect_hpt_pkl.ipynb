# %%
import pickle
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sys.path.append('streamlit/scripts') 

import pop_ga

# %%
res_pkl_path = 'streamlit/assets/hpt_actual_selected_res_2.pkl'
file_size = os.path.getsize(res_pkl_path)
print(f"The size of '{res_pkl_path}' is {file_size} bytes.")
# Out:
# The size of 'streamlit/assets/hpt_actual_selected_res_2.pkl' is 1734242215 bytes.

# %%
with open(res_pkl_path, 'rb') as f:
    result_dict = pickle.load(f)

# %%
result_dict
# Out:
# [{'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x156136440>,
#   'objective_value': -70997.50015636685,
#   'elapsed_time': 210.40265703201294},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x157943100>,
#   'objective_value': -70975.24842109028,
#   'elapsed_time': 411.0201609134674},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x15d8a2d10>,
#   'objective_value': -70896.91505522694,
#   'elapsed_time': 410.1004719734192},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x15f4db430>,
#   'objective_value': -70830.1575942664,
#   'elapsed_time': 413.54667925834656},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x16b3363b0>,
#   'objective_value': -70658.37813596158,
#   'elapsed_time': 282.9681589603424},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x16cff5750>,
#   'objective_value': -70542.02379276471,
#   'elapsed_time': 148.54014801979065},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x311022350>,
#   'objective_value': -70285.45612561813,
#   'elapsed_time': 224.03125381469727},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x31378ab90>,
#   'objective_value': -70137.07179023666,
#   'elapsed_time': 267.26724767684937},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x315c60ac0>,
#   'objective_value': -69912.11038159703,
#   'elapsed_time': 277.2166690826416},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x33a189180>,
#   'objective_value': -69749.86943370735,
#   'elapsed_time': 200.94905614852905},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x33e85f100>,
#   'objective_value': -69724.5077801412,
#   'elapsed_time': 230.3623468875885},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x35285a7d0>,
#   'objective_value': -69310.63012289927,
#   'elapsed_time': 159.77542114257812}]

# %%
sorted_results = sorted(result_dict, key=lambda x: x["objective_value"])
sorted_results
# Out:
# [{'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.4,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x156136440>,
#   'objective_value': -70997.50015636685,
#   'elapsed_time': 210.40265703201294},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x157943100>,
#   'objective_value': -70975.24842109028,
#   'elapsed_time': 411.0201609134674},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x15d8a2d10>,
#   'objective_value': -70896.91505522694,
#   'elapsed_time': 410.1004719734192},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x15f4db430>,
#   'objective_value': -70830.1575942664,
#   'elapsed_time': 413.54667925834656},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x16b3363b0>,
#   'objective_value': -70658.37813596158,
#   'elapsed_time': 282.9681589603424},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.2,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x16cff5750>,
#   'objective_value': -70542.02379276471,
#   'elapsed_time': 148.54014801979065},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.8,
#   'mutation': 'PolynomialMutation',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x311022350>,
#   'objective_value': -70285.45612561813,
#   'elapsed_time': 224.03125381469727},
#  {'crossover': 'SwapCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.2,
#   'result': <pymoo.core.result.Result at 0x31378ab90>,
#   'objective_value': -70137.07179023666,
#   'elapsed_time': 267.26724767684937},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'SwapMutation',
#   'mutation_prob': 0.4,
#   'result': <pymoo.core.result.Result at 0x315c60ac0>,
#   'objective_value': -69912.11038159703,
#   'elapsed_time': 277.2166690826416},
#  {'crossover': 'SinglePointCrossover',
#   'crossover_prob': 0.8,
#   'mutation': 'BFM',
#   'mutation_prob': 0.8,
#   'result': <pymoo.core.result.Result at 0x33a189180>,
#   'objective_value': -69749.86943370735,
#   'elapsed_time': 200.94905614852905},
#  {'crossover': 'TwoPointCrossover',
#   'crossover_prob': 0.6,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x33e85f100>,
#   'objective_value': -69724.5077801412,
#   'elapsed_time': 230.3623468875885},
#  {'crossover': 'SBX',
#   'crossover_prob': 0.2,
#   'mutation': 'BFM',
#   'mutation_prob': 0.6,
#   'result': <pymoo.core.result.Result at 0x35285a7d0>,
#   'objective_value': -69310.63012289927,
#   'elapsed_time': 159.77542114257812}]

# %%
df = pd.DataFrame(sorted_results)

# Remove the 'result' column from the DataFrame
df.drop(columns=['result'], inplace=True)
df
# Out:
#                crossover  crossover_prob            mutation  mutation_prob  \
# 0      TwoPointCrossover             0.4  PolynomialMutation            0.6
# 1   SinglePointCrossover             0.2        SwapMutation            0.8
# 2          SwapCrossover             0.8        SwapMutation            0.4
# 3      TwoPointCrossover             0.8        SwapMutation            0.8
# 4          SwapCrossover             0.8  PolynomialMutation            0.2
# 5   SinglePointCrossover             0.2  PolynomialMutation            0.8
# 6                    SBX             0.8  PolynomialMutation            0.8
# 7          SwapCrossover             0.6                 BFM            0.2
# 8                    SBX             0.2        SwapMutation            0.4
# 9   SinglePointCrossover             0.8                 BFM            0.8
# 10     TwoPointCrossover             0.6                 BFM            0.6
# 11                   SBX             0.2                 BFM            0.6
#
#     objective_value  elapsed_time
# 0     -70997.500156    210.402657
# 1     -70975.248421    411.020161
# 2     -70896.915055    410.100472
# 3     -70830.157594    413.546679
# 4     -70658.378136    282.968159
# 5     -70542.023793    148.540148
# 6     -70285.456126    224.031254
# 7     -70137.071790    267.267248
# 8     -69912.110382    277.216669
# 9     -69749.869434    200.949056
# 10    -69724.507780    230.362347
# 11    -69310.630123    159.775421

# %%
import matplotlib

# %matplotlib qt

for idx, r in enumerate(result_dict):
    label = f'{r["crossover"]} {r["crossover_prob"]} {r["mutation"]} {r["mutation_prob"]}'
    n_evals = np.array([e.evaluator.n_eval for e in r["result"].history])
    opt = np.array([e.opt[0].F for e in r["result"].history])
    
    if idx == 0:
        plt.plot(n_evals, opt, label=label, linestyle='solid', linewidth=2)
    elif idx == 1:
        plt.plot(n_evals, opt, label=label, linestyle='--', linewidth=2)
    else:
        plt.plot(n_evals, opt, label=label, linestyle='dotted', linewidth=1, alpha=0.8)


plt.title("Analysis of Convergence")
plt.xlabel("n_eval")
plt.ylabel("f_min")
plt.legend(loc="lower left", fontsize="small")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 3
#       1 import matplotlib
# ----> 3 get_ipython().run_line_magic('matplotlib', 'qt')
#       5 for idx, r in enumerate(result_dict):
#       6     label = f'{r["crossover"]} {r["crossover_prob"]} {r["mutation"]} {r["mutation_prob"]}'
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/google-or-tools/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/google-or-tools/lib/python3.10/site-packages/IPython/core/magics/pylab.py:99, in PylabMagics.matplotlib(self, line)
#      97     print("Available matplotlib backends: %s" % backends_list)
#      98 else:
# ---> 99     gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100     self._show_matplotlib_backend(args.gui, backend)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/google-or-tools/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3670, in InteractiveShell.enable_matplotlib(self, gui)
#    3666         print('Warning: Cannot change to a different GUI toolkit: %s.'
#    3667                 ' Using %s instead.' % (gui, self.pylab_gui_select))
#    3668         gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
# -> 3670 pt.activate_matplotlib(backend)
#    3672 from matplotlib_inline.backend_inline import configure_inline_support
#    3674 configure_inline_support(self, backend)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/google-or-tools/lib/python3.10/site-packages/IPython/core/pylabtools.py:368, in activate_matplotlib(backend)
#     363 # Due to circular imports, pyplot may be only partially initialised
#     364 # when this function runs.
#     365 # So avoid needing matplotlib attribute-lookup to access pyplot.
#     366 from matplotlib import pyplot as plt
# --> 368 plt.switch_backend(backend)
#     370 plt.show._needmain = False
#     371 # We need to detect at runtime whether show() is called by the user.
#     372 # For this, we wrap it into a decorator which adds a 'called' flag.
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/google-or-tools/lib/python3.10/site-packages/matplotlib/pyplot.py:342, in switch_backend(newbackend)
#     339 # have to escape the switch on access logic
#     340 old_backend = dict.__getitem__(rcParams, 'backend')
# --> 342 module = importlib.import_module(cbook._backend_module_name(newbackend))
#     343 canvas_class = module.FigureCanvas
#     345 required_framework = canvas_class.required_interactive_framework
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/google-or-tools/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/google-or-tools/lib/python3.10/site-packages/matplotlib/backends/backend_qtagg.py:9
#       5 import ctypes
#       7 from matplotlib.transforms import Bbox
# ----> 9 from .qt_compat import QT_API, QtCore, QtGui
#      10 from .backend_agg import FigureCanvasAgg
#      11 from .backend_qt import _BackendQT, FigureCanvasQT
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/google-or-tools/lib/python3.10/site-packages/matplotlib/backends/qt_compat.py:133
#     131         break
#     132     else:
# --> 133         raise ImportError(
#     134             "Failed to import any of the following Qt binding modules: {}"
#     135             .format(", ".join([QT_API for _, QT_API in _candidates]))
#     136         )
#     137 else:  # We should not get there.
#     138     raise AssertionError(f"Unexpected QT_API: {QT_API}")
#
# ImportError: Failed to import any of the following Qt binding modules: PyQt6, PySide6, PyQt5, PySide2
